# %% [markdown]
# <a href="https://colab.research.google.com/github/Chamchis/likelion_learn_colab/blob/main/KJH_day11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
# 1차원 벡터, 열 벡터 cf) list
a = [1,2,3,4,5]
sr = pd.Series(a)

# %%
sr
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
type(sr)
# Out:
# pandas.core.series.Series

# %%
# 2차원 구조
df = pd.DataFrame(a)
df
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4
# 4  5

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
a = np.random.rand(3,5)
a
# Out:
# array([[0.13234972, 0.40863815, 0.98463115, 0.1082373 , 0.82754418],
#        [0.79996527, 0.93969661, 0.39554559, 0.69679382, 0.99033517],
#        [0.33027785, 0.14917159, 0.96444869, 0.45926317, 0.44735317]])

# %%
pd.DataFrame(a)
# Out:
#           0         1         2         3         4
# 0  0.132350  0.408638  0.984631  0.108237  0.827544
# 1  0.799965  0.939697  0.395546  0.696794  0.990335
# 2  0.330278  0.149172  0.964449  0.459263  0.447353

# %%
company = [
    ['한국갤럽', 1000, '데이터처리부서 통계 검증 & 지수산출 분야'],
    ['플럭스코리아', 1500, '온오프라인 교육 플랫폼 설계 및 제작'],
    ['굿어스', 2000, '클라우드 개발분야'],
    ['STK', 2500, '글로벌빅데이터 플랫폼 및 보안솔루션 컨설팅'],
    ['에스넷시스템', 3000, '네트워킹 구축 솔루션 제공'],
    ['리서치앤리서치', 3500, '리서치 자료의 데이터 분석 및 처리부서'],
    ['인성정보',4000, '클라우드, 데이터 센터 등 IT 업무환경 구축'],
    ['골든플래닛', 4500, '데이터 마케팅을 위한 데이터 수집 및 가공분야'],
    ['크립티드', 5000, '블록체인 개발 부문'],
    ['모멘티', 5500, 'IT 프로젝트 수행 전문 기업']
]

# %%
pd.DataFrame(company)
# Out:
#          0     1                          2
# 0     한국갤럽  1000    데이터처리부서 통계 검증 & 지수산출 분야
# 1   플럭스코리아  1500       온오프라인 교육 플랫폼 설계 및 제작
# 2      굿어스  2000                  클라우드 개발분야
# 3      STK  2500    글로벌빅데이터 플랫폼 및 보안솔루션 컨설팅
# 4   에스넷시스템  3000             네트워킹 구축 솔루션 제공
# 5  리서치앤리서치  3500      리서치 자료의 데이터 분석 및 처리부서
# 6     인성정보  4000  클라우드, 데이터 센터 등 IT 업무환경 구축
# 7    골든플래닛  4500  데이터 마케팅을 위한 데이터 수집 및 가공분야
# 8     크립티드  5000                 블록체인 개발 부문
# 9      모멘티  5500           IT 프로젝트 수행 전문 기업

# %%
df_company = pd.DataFrame(company)
df_company
# Out:
#          0     1                          2
# 0     한국갤럽  1000    데이터처리부서 통계 검증 & 지수산출 분야
# 1   플럭스코리아  1500       온오프라인 교육 플랫폼 설계 및 제작
# 2      굿어스  2000                  클라우드 개발분야
# 3      STK  2500    글로벌빅데이터 플랫폼 및 보안솔루션 컨설팅
# 4   에스넷시스템  3000             네트워킹 구축 솔루션 제공
# 5  리서치앤리서치  3500      리서치 자료의 데이터 분석 및 처리부서
# 6     인성정보  4000  클라우드, 데이터 센터 등 IT 업무환경 구축
# 7    골든플래닛  4500  데이터 마케팅을 위한 데이터 수집 및 가공분야
# 8     크립티드  5000                 블록체인 개발 부문
# 9      모멘티  5500           IT 프로젝트 수행 전문 기업

# %%
df_company.columns
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df_company.columns = ['기업명', '매출액', '업무']
df_company
# Out:
#        기업명   매출액                         업무
# 0     한국갤럽  1000    데이터처리부서 통계 검증 & 지수산출 분야
# 1   플럭스코리아  1500       온오프라인 교육 플랫폼 설계 및 제작
# 2      굿어스  2000                  클라우드 개발분야
# 3      STK  2500    글로벌빅데이터 플랫폼 및 보안솔루션 컨설팅
# 4   에스넷시스템  3000             네트워킹 구축 솔루션 제공
# 5  리서치앤리서치  3500      리서치 자료의 데이터 분석 및 처리부서
# 6     인성정보  4000  클라우드, 데이터 센터 등 IT 업무환경 구축
# 7    골든플래닛  4500  데이터 마케팅을 위한 데이터 수집 및 가공분야
# 8     크립티드  5000                 블록체인 개발 부문
# 9      모멘티  5500           IT 프로젝트 수행 전문 기업

# %%
company_dict = {
    '기업명': ['한국갤럽', '플럭스코리아', '굿어스', 'STK', '에스넷시스템', '리서치앤리서치', '인성정보', '골든플래닛', '크립티드', '모멘티'],
    '매출액': [1000, 1500, 2000, 2500, 3000, 3500, 4000, 4500, 5000, 5500],
    '업무': [
        '데이터처리부서 통계 검증 & 지수산출 분야',
        '온오프라인 교육 플랫폼 설계 및 제작',
        '클라우드 개발분야',
        '글로벌빅데이터 플랫폼 및 보안솔루션 컨설팅',
        '네트워킹 구축 솔루션 제공',
        '리서치 자료의 데이터 분석 및 처리부서',
        '클라우드, 데이터 센터 등 IT 업무환경 구축',
        '데이터 마케팅을 위한 데이터 수집 및 가공분야',
        '블록체인 개발 부문',
        'IT 프로젝트 수행 전문 기업'
    ]
}
company_dict
# Out:
# {'기업명': ['한국갤럽',
#   '플럭스코리아',
#   '굿어스',
#   'STK',
#   '에스넷시스템',
#   '리서치앤리서치',
#   '인성정보',
#   '골든플래닛',
#   '크립티드',
#   '모멘티'],
#  '매출액': [1000, 1500, 2000, 2500, 3000, 3500, 4000, 4500, 5000, 5500],
#  '업무': ['데이터처리부서 통계 검증 & 지수산출 분야',
#   '온오프라인 교육 플랫폼 설계 및 제작',
#   '클라우드 개발분야',
#   '글로벌빅데이터 플랫폼 및 보안솔루션 컨설팅',
#   '네트워킹 구축 솔루션 제공',
#   '리서치 자료의 데이터 분석 및 처리부서',
#   '클라우드, 데이터 센터 등 IT 업무환경 구축',
#   '데이터 마케팅을 위한 데이터 수집 및 가공분야',
#   '블록체인 개발 부문',
#   'IT 프로젝트 수행 전문 기업']}

# %%
df_company = pd.DataFrame(company_dict)
df_company
# Out:
#        기업명   매출액                         업무
# 0     한국갤럽  1000    데이터처리부서 통계 검증 & 지수산출 분야
# 1   플럭스코리아  1500       온오프라인 교육 플랫폼 설계 및 제작
# 2      굿어스  2000                  클라우드 개발분야
# 3      STK  2500    글로벌빅데이터 플랫폼 및 보안솔루션 컨설팅
# 4   에스넷시스템  3000             네트워킹 구축 솔루션 제공
# 5  리서치앤리서치  3500      리서치 자료의 데이터 분석 및 처리부서
# 6     인성정보  4000  클라우드, 데이터 센터 등 IT 업무환경 구축
# 7    골든플래닛  4500  데이터 마케팅을 위한 데이터 수집 및 가공분야
# 8     크립티드  5000                 블록체인 개발 부문
# 9      모멘티  5500           IT 프로젝트 수행 전문 기업

# %%
df_company.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
df_company.index = df_company['기업명']
df_company
# Out:
#              기업명   매출액                         업무
# 기업명
# 한국갤럽        한국갤럽  1000    데이터처리부서 통계 검증 & 지수산출 분야
# 플럭스코리아    플럭스코리아  1500       온오프라인 교육 플랫폼 설계 및 제작
# 굿어스          굿어스  2000                  클라우드 개발분야
# STK          STK  2500    글로벌빅데이터 플랫폼 및 보안솔루션 컨설팅
# 에스넷시스템    에스넷시스템  3000             네트워킹 구축 솔루션 제공
# 리서치앤리서치  리서치앤리서치  3500      리서치 자료의 데이터 분석 및 처리부서
# 인성정보        인성정보  4000  클라우드, 데이터 센터 등 IT 업무환경 구축
# 골든플래닛      골든플래닛  4500  데이터 마케팅을 위한 데이터 수집 및 가공분야
# 크립티드        크립티드  5000                 블록체인 개발 부문
# 모멘티          모멘티  5500           IT 프로젝트 수행 전문 기업

# %%
df_company['기업명']
# Out:
# 기업명
# 한국갤럽          한국갤럽
# 플럭스코리아      플럭스코리아
# 굿어스            굿어스
# STK            STK
# 에스넷시스템      에스넷시스템
# 리서치앤리서치    리서치앤리서치
# 인성정보          인성정보
# 골든플래닛        골든플래닛
# 크립티드          크립티드
# 모멘티            모멘티
# Name: 기업명, dtype: object

# %%
df_company['업무']
# Out:
# 기업명
# 한국갤럽         데이터처리부서 통계 검증 & 지수산출 분야
# 플럭스코리아          온오프라인 교육 플랫폼 설계 및 제작
# 굿어스                        클라우드 개발분야
# STK          글로벌빅데이터 플랫폼 및 보안솔루션 컨설팅
# 에스넷시스템                네트워킹 구축 솔루션 제공
# 리서치앤리서치        리서치 자료의 데이터 분석 및 처리부서
# 인성정보       클라우드, 데이터 센터 등 IT 업무환경 구축
# 골든플래닛      데이터 마케팅을 위한 데이터 수집 및 가공분야
# 크립티드                      블록체인 개발 부문
# 모멘티                 IT 프로젝트 수행 전문 기업
# Name: 업무, dtype: object

# %%
df_company
# Out:
#              기업명   매출액                         업무
# 기업명
# 한국갤럽        한국갤럽  1000    데이터처리부서 통계 검증 & 지수산출 분야
# 플럭스코리아    플럭스코리아  1500       온오프라인 교육 플랫폼 설계 및 제작
# 굿어스          굿어스  2000                  클라우드 개발분야
# STK          STK  2500    글로벌빅데이터 플랫폼 및 보안솔루션 컨설팅
# 에스넷시스템    에스넷시스템  3000             네트워킹 구축 솔루션 제공
# 리서치앤리서치  리서치앤리서치  3500      리서치 자료의 데이터 분석 및 처리부서
# 인성정보        인성정보  4000  클라우드, 데이터 센터 등 IT 업무환경 구축
# 골든플래닛      골든플래닛  4500  데이터 마케팅을 위한 데이터 수집 및 가공분야
# 크립티드        크립티드  5000                 블록체인 개발 부문
# 모멘티          모멘티  5500           IT 프로젝트 수행 전문 기업

# %%
df_company[['기업명','업무']]
# Out:
#              기업명                         업무
# 기업명
# 한국갤럽        한국갤럽    데이터처리부서 통계 검증 & 지수산출 분야
# 플럭스코리아    플럭스코리아       온오프라인 교육 플랫폼 설계 및 제작
# 굿어스          굿어스                  클라우드 개발분야
# STK          STK    글로벌빅데이터 플랫폼 및 보안솔루션 컨설팅
# 에스넷시스템    에스넷시스템             네트워킹 구축 솔루션 제공
# 리서치앤리서치  리서치앤리서치      리서치 자료의 데이터 분석 및 처리부서
# 인성정보        인성정보  클라우드, 데이터 센터 등 IT 업무환경 구축
# 골든플래닛      골든플래닛  데이터 마케팅을 위한 데이터 수집 및 가공분야
# 크립티드        크립티드                 블록체인 개발 부문
# 모멘티          모멘티           IT 프로젝트 수행 전문 기업

# %%
df = pd.read_csv('서울시설공단_서울월드컵경기장 주경기장 사용자 통계_20221231.csv', encoding='cp949')

# %%
df
# Out:
#         연번         경기(행사) 일시   구 분          경기(행사) 종류          경기(행사) 내용  \
# 0      1.0  2015-02-17 19:30  기타축구                ACL   ACL(vs하노이T&T FC)
# 1      2.0  2015-03-04 19:30  기타축구                ACL     ACL(vs가시마앤틀러스)
# 2      3.0  2015-03-14 14:00   K리그            K리그 클래식      K리그 클래식(vs전북)
# 3      4.0  2015-03-18 19:30  기타축구                ACL      ACL(vs웨스턴시드니)
# 4      5.0  2015-03-31 20:00  국가대표         국가대표팀 친선경기       친선경기(vs뉴질랜드)
# ..     ...               ...   ...                ...                ...
# 279  280.0  2022-11-26 15:00  기타축구  제12회 한일 국회의원 축구대회  제12회 한일 국회의원 축구대회
# 280    NaN               NaN   NaN                NaN                NaN
# 281    NaN               NaN   NaN                NaN                NaN
# 282    NaN               NaN   NaN                NaN                NaN
# 283    NaN               NaN   NaN                NaN                NaN
#
#                 주 최   관람인원(명)        수입금(원)  사용일수(일)
# ...

# %%
df.columns
# Out:
# Index(['연번', '경기(행사) 일시', '구 분', '경기(행사) 종류', '경기(행사) 내용', '주 최', ' 관람인원(명) ',
#        '수입금(원)', '사용일수(일)'],
#       dtype='object')

# %%
tmp_columns = list(df.columns)

# %%
tmp_columns[0]='년도'

# %%
df.columns = tmp_columns
df
# Out:
#         년도         경기(행사) 일시   구 분          경기(행사) 종류          경기(행사) 내용  \
# 0      1.0  2015-02-17 19:30  기타축구                ACL   ACL(vs하노이T&T FC)
# 1      2.0  2015-03-04 19:30  기타축구                ACL     ACL(vs가시마앤틀러스)
# 2      3.0  2015-03-14 14:00   K리그            K리그 클래식      K리그 클래식(vs전북)
# 3      4.0  2015-03-18 19:30  기타축구                ACL      ACL(vs웨스턴시드니)
# 4      5.0  2015-03-31 20:00  국가대표         국가대표팀 친선경기       친선경기(vs뉴질랜드)
# ..     ...               ...   ...                ...                ...
# 279  280.0  2022-11-26 15:00  기타축구  제12회 한일 국회의원 축구대회  제12회 한일 국회의원 축구대회
# 280    NaN               NaN   NaN                NaN                NaN
# 281    NaN               NaN   NaN                NaN                NaN
# 282    NaN               NaN   NaN                NaN                NaN
# 283    NaN               NaN   NaN                NaN                NaN
#
#                 주 최   관람인원(명)        수입금(원)  사용일수(일)
# ...

# %%
df.head()
# Out:
#     년도         경기(행사) 일시   구 분   경기(행사) 종류         경기(행사) 내용     주 최  \
# 0  1.0  2015-02-17 19:30  기타축구         ACL  ACL(vs하노이T&T FC)   GS스포츠
# 1  2.0  2015-03-04 19:30  기타축구         ACL    ACL(vs가시마앤틀러스)   GS스포츠
# 2  3.0  2015-03-14 14:00   K리그     K리그 클래식     K리그 클래식(vs전북)   GS스포츠
# 3  4.0  2015-03-18 19:30  기타축구         ACL     ACL(vs웨스턴시드니)   GS스포츠
# 4  5.0  2015-03-31 20:00  국가대표  국가대표팀 친선경기      친선경기(vs뉴질랜드)  대한축구협회
#
#     관람인원(명)        수입금(원)  사용일수(일)
# 0     6718.0   23835150.0      3.0
# 1     5790.0   27579990.0      2.0
# 2    32516.0   53033020.0      1.0
# 3     5645.0   26955470.0      2.0
# 4    28574.0  152907970.0      3.0

# %%
df.tail()
# Out:
#         년도         경기(행사) 일시   구 분          경기(행사) 종류          경기(행사) 내용  \
# 279  280.0  2022-11-26 15:00  기타축구  제12회 한일 국회의원 축구대회  제12회 한일 국회의원 축구대회
# 280    NaN               NaN   NaN                NaN                NaN
# 281    NaN               NaN   NaN                NaN                NaN
# 282    NaN               NaN   NaN                NaN                NaN
# 283    NaN               NaN   NaN                NaN                NaN
#
#                 주 최   관람인원(명)      수입금(원)  사용일수(일)
# 279  국회사무처(국제국 아태과)      120.0  3435160.0      1.0
# 280             NaN        NaN        NaN      NaN
# 281             NaN        NaN        NaN      NaN
# 282             NaN        NaN        NaN      NaN
# 283             NaN        NaN        NaN      NaN

# %%
df.describe()
# Out:
#                년도      관람인원(명)         수입금(원)     사용일수(일)
# count  280.000000    279.000000  2.790000e+02  280.000000
# mean   140.500000  13249.347670  5.750238e+07    1.600000
# std     80.973247  15845.899087  1.177398e+08    1.679734
# min      1.000000      0.000000  0.000000e+00    0.000000
# 25%     70.750000    220.000000  1.603560e+07    1.000000
# 50%    140.500000   8609.000000  3.781547e+07    1.000000
# 75%    210.250000  17773.000000  4.917414e+07    1.000000
# max    280.000000  65608.000000  1.220458e+09   12.000000

# %%
df.shape
# Out:
# (284, 9)

# %%
df.sort_index()
# Out:
#         년도         경기(행사) 일시   구 분          경기(행사) 종류          경기(행사) 내용  \
# 0      1.0  2015-02-17 19:30  기타축구                ACL   ACL(vs하노이T&T FC)
# 1      2.0  2015-03-04 19:30  기타축구                ACL     ACL(vs가시마앤틀러스)
# 2      3.0  2015-03-14 14:00   K리그            K리그 클래식      K리그 클래식(vs전북)
# 3      4.0  2015-03-18 19:30  기타축구                ACL      ACL(vs웨스턴시드니)
# 4      5.0  2015-03-31 20:00  국가대표         국가대표팀 친선경기       친선경기(vs뉴질랜드)
# ..     ...               ...   ...                ...                ...
# 279  280.0  2022-11-26 15:00  기타축구  제12회 한일 국회의원 축구대회  제12회 한일 국회의원 축구대회
# 280    NaN               NaN   NaN                NaN                NaN
# 281    NaN               NaN   NaN                NaN                NaN
# 282    NaN               NaN   NaN                NaN                NaN
# 283    NaN               NaN   NaN                NaN                NaN
#
#                 주 최   관람인원(명)        수입금(원)  사용일수(일)
# ...

# %%
df.sort_index(ascending=False)
# Out:
#         년도         경기(행사) 일시   구 분          경기(행사) 종류          경기(행사) 내용  \
# 283    NaN               NaN   NaN                NaN                NaN
# 282    NaN               NaN   NaN                NaN                NaN
# 281    NaN               NaN   NaN                NaN                NaN
# 280    NaN               NaN   NaN                NaN                NaN
# 279  280.0  2022-11-26 15:00  기타축구  제12회 한일 국회의원 축구대회  제12회 한일 국회의원 축구대회
# ..     ...               ...   ...                ...                ...
# 4      5.0  2015-03-31 20:00  국가대표         국가대표팀 친선경기       친선경기(vs뉴질랜드)
# 3      4.0  2015-03-18 19:30  기타축구                ACL      ACL(vs웨스턴시드니)
# 2      3.0  2015-03-14 14:00   K리그            K리그 클래식      K리그 클래식(vs전북)
# 1      2.0  2015-03-04 19:30  기타축구                ACL     ACL(vs가시마앤틀러스)
# 0      1.0  2015-02-17 19:30  기타축구                ACL   ACL(vs하노이T&T FC)
#
#                 주 최   관람인원(명)        수입금(원)  사용일수(일)
# ...

# %%
df.sort_index(ascending=False)
# Out:
#         년도         경기(행사) 일시   구 분          경기(행사) 종류          경기(행사) 내용  \
# 283    NaN               NaN   NaN                NaN                NaN
# 282    NaN               NaN   NaN                NaN                NaN
# 281    NaN               NaN   NaN                NaN                NaN
# 280    NaN               NaN   NaN                NaN                NaN
# 279  280.0  2022-11-26 15:00  기타축구  제12회 한일 국회의원 축구대회  제12회 한일 국회의원 축구대회
# ..     ...               ...   ...                ...                ...
# 4      5.0  2015-03-31 20:00  국가대표         국가대표팀 친선경기       친선경기(vs뉴질랜드)
# 3      4.0  2015-03-18 19:30  기타축구                ACL      ACL(vs웨스턴시드니)
# 2      3.0  2015-03-14 14:00   K리그            K리그 클래식      K리그 클래식(vs전북)
# 1      2.0  2015-03-04 19:30  기타축구                ACL     ACL(vs가시마앤틀러스)
# 0      1.0  2015-02-17 19:30  기타축구                ACL   ACL(vs하노이T&T FC)
#
#                 주 최   관람인원(명)        수입금(원)  사용일수(일)
# ...

# %%
#df.sort_index(ascending=False, inplace=True)
df_desc = df.sort_index(ascending=False)

# %%
df.sort_values(by='수입금(원)')
# Out:
#         연번         경기(행사) 일시   구 분                    경기(행사) 종류  \
# 204  205.0  2019-10-08 13:00  기타축구                 제100회 전국체육대회
# 205  206.0  2019-10-10 14:00  기타축구                 제100회 전국체육대회
# 19    20.0  2015-06-21 15:00  기타축구                 서울컵2015 전기결승
# 207  208.0  2019-10-16 10:00  기타축구                   제39회 장애인체전
# 141  142.0  2017-07-17 09:00  일반행사                     프린지 페스티벌
# ..     ...               ...   ...                          ...
# 191  192.0  2019-06-16 01:00  국가대표  2019 FIFA U-20 월드컵 결승 거리응원전
# 280    NaN               NaN   NaN                          NaN
# 281    NaN               NaN   NaN                          NaN
# 282    NaN               NaN   NaN                          NaN
# 283    NaN               NaN   NaN                          NaN
#
#                        경기(행사) 내용            주 최   관람인원(명)   수입금(원)  사용일수(일)
# 204          제100회 전국체육대회 4강 2차전          서울특별시      350.0     0.0      0.0
# ...

# %%
df.sort_values(by='수입금(원)', ascending=False)
# Out:
#         연번         경기(행사) 일시   구 분                          경기(행사) 종류  \
# 267  268.0  2022-07-13 20:00  일반행사  2022 쿠팡플레이시리즈 친선경기 (팀K리그 vs.토트넘)
# 196  197.0  2019-07-26 20:00  일반행사                    K리그 올스타vs유벤투스FC
# 262  263.0  2022-06-02 20:00  국가대표                         국가대표팀 친선경기
# 86    87.0  2016-08-20 19:00  일반행사                                콘서트
# 263  264.0  2022-06-14 20:00  국가대표                         국가대표팀 친선경기
# ..     ...               ...   ...                                ...
# 191  192.0  2019-06-16 01:00  국가대표        2019 FIFA U-20 월드컵 결승 거리응원전
# 280    NaN               NaN   NaN                                NaN
# 281    NaN               NaN   NaN                                NaN
# 282    NaN               NaN   NaN                                NaN
# 283    NaN               NaN   NaN                                NaN
#
#                              경기(행사) 내용                주 최   관람인원(명)   \
# ...

# %%
df.sort_values(by=['구 분', '주 최'])
# Out:
#         년도         경기(행사) 일시   구 분 경기(행사) 종류         경기(행사) 내용        주 최  \
# 155  156.0  2018-03-11 16:00   K리그   K리그 클래식  2018 K리그1 서울vs강원   (주)GS스포츠
# 156  157.0  2018-04-01 14:00   K리그   K리그 클래식  2018 K리그1 서울vs인천   (주)GS스포츠
# 158  159.0  2018-04-11 19:00   K리그   K리그 클래식  2018 K리그1 서울vs포항   (주)GS스포츠
# 159  160.0  2018-04-21 14:00   K리그   K리그 클래식  2018 K리그1 서울vs대구   (주)GS스포츠
# 160  161.0  2018-04-28 16:00   K리그   K리그 클래식  2018 K리그1 서울vs상주   (주)GS스포츠
# ..     ...               ...   ...       ...               ...        ...
# 188  189.0  2019-05-18 18:00  일반행사       콘서트        2019 드림콘서트  한국연예제작자협회
# 280    NaN               NaN   NaN       NaN               NaN        NaN
# 281    NaN               NaN   NaN       NaN               NaN        NaN
# 282    NaN               NaN   NaN       NaN               NaN        NaN
# 283    NaN               NaN   NaN       NaN               NaN        NaN
#
#       관람인원(명)       수입금(원)  사용일수(일)
# 155    16506.0  42307060.0      1.0
# ...

# %%
df['구 분'].apply(lambda x : 'K리그' if x ==1 else '일반행사')
# Out:
# 0      일반행사
# 1      일반행사
# 2      일반행사
# 3      일반행사
# 4      일반행사
#        ...
# 279    일반행사
# 280    일반행사
# 281    일반행사
# 282    일반행사
# 283    일반행사
# Name: 구 분, Length: 284, dtype: object

# %%
df['수입금(원)'].min(), df['수입금(원)'].max()
# Out:
# (0.0, 1220458130.0)

# %%
df['수입금(원)'].min(), df['수입금(원)'].max(), df['수입금(원)'].var(), df['수입금(원)'].std()
# Out:
# (0.0, 1220458130.0, 1.3862658062690226e+16, 117739789.63243575)

# %%
df['수입금(원)'].count()
# Out:
# 279

# %%
df['수입금(원)'].mode()
# Out:
# 0    0.0
# Name: 수입금(원), dtype: float64

# %%
df.loc[3,['수입금(원)','주 최']]
# Out:
# 수입금(원)    26955470.0
# 주 최            GS스포츠
# Name: 3, dtype: object

# %%
df.groupby('수입금(원)').count()
# Out:
#               연번  경기(행사) 일시  구 분  경기(행사) 종류  경기(행사) 내용  주 최   관람인원(명)   \
# 수입금(원)
# 0.000000e+00  23         23   23         23         23   23         23
# 3.545100e+05   1          1    1          1          1    1          1
# 4.115800e+05   1          1    1          1          1    1          1
# 4.600000e+05   4          4    4          4          4    4          4
# 5.980000e+05   7          7    7          7          7    7          7
# ...           ..        ...  ...        ...        ...  ...        ...
# 4.854483e+08   1          1    1          1          1    1          1
# 5.752706e+08   1          1    1          1          1    1          1
# 5.975684e+08   1          1    1          1          1    1          1
# 9.128284e+08   1          1    1          1          1    1          1
# 1.220458e+09   1          1    1          1          1    1          1
#
#               사용일수(일)
# 수입금(원)
# 0.000000e+00       23
# 3.545100e+05        1
# 4.115800e+05        1
# ...

# %%
df.value_counts('수입금(원)',normalize=True)
# Out:
# 수입금(원)
# 0.000000e+00    0.082437
# 8.970000e+05    0.046595
# 5.980000e+05    0.025090
# 4.600000e+05    0.014337
# 7.140000e+05    0.007168
#                   ...
# 3.588053e+07    0.003584
# 3.605357e+07    0.003584
# 3.621042e+07    0.003584
# 3.652861e+07    0.003584
# 1.220458e+09    0.003584
# Length: 235, dtype: float64

# %%
df.drop('수입금(원)', axis=1)
# Out:
#         연번         경기(행사) 일시   구 분          경기(행사) 종류          경기(행사) 내용  \
# 0      1.0  2015-02-17 19:30  기타축구                ACL   ACL(vs하노이T&T FC)
# 1      2.0  2015-03-04 19:30  기타축구                ACL     ACL(vs가시마앤틀러스)
# 2      3.0  2015-03-14 14:00   K리그            K리그 클래식      K리그 클래식(vs전북)
# 3      4.0  2015-03-18 19:30  기타축구                ACL      ACL(vs웨스턴시드니)
# 4      5.0  2015-03-31 20:00  국가대표         국가대표팀 친선경기       친선경기(vs뉴질랜드)
# ..     ...               ...   ...                ...                ...
# 279  280.0  2022-11-26 15:00  기타축구  제12회 한일 국회의원 축구대회  제12회 한일 국회의원 축구대회
# 280    NaN               NaN   NaN                NaN                NaN
# 281    NaN               NaN   NaN                NaN                NaN
# 282    NaN               NaN   NaN                NaN                NaN
# 283    NaN               NaN   NaN                NaN                NaN
#
#                 주 최   관람인원(명)   사용일수(일)
# 0             GS스포츠     6718.0      3.0
# ...

# %%
df.drop([0], axis=0)
# Out:
#         연번         경기(행사) 일시   구 분          경기(행사) 종류          경기(행사) 내용  \
# 1      2.0  2015-03-04 19:30  기타축구                ACL     ACL(vs가시마앤틀러스)
# 2      3.0  2015-03-14 14:00   K리그            K리그 클래식      K리그 클래식(vs전북)
# 3      4.0  2015-03-18 19:30  기타축구                ACL      ACL(vs웨스턴시드니)
# 4      5.0  2015-03-31 20:00  국가대표         국가대표팀 친선경기       친선경기(vs뉴질랜드)
# 5      6.0  2015-04-04 14:00   K리그            K리그 클래식   K리그 클래식-4R(vs제주)
# ..     ...               ...   ...                ...                ...
# 279  280.0  2022-11-26 15:00  기타축구  제12회 한일 국회의원 축구대회  제12회 한일 국회의원 축구대회
# 280    NaN               NaN   NaN                NaN                NaN
# 281    NaN               NaN   NaN                NaN                NaN
# 282    NaN               NaN   NaN                NaN                NaN
# 283    NaN               NaN   NaN                NaN                NaN
#
#                 주 최   관람인원(명)        수입금(원)  사용일수(일)
# ...

# %%
import logging

# 기본 로거를 구성하고, 로깅 레벨을 설정
logging.basicConfig(level=logging.INFO)

# 로깅 메시지 작성
logging.info("This is an info message")
logging.warning("This is a warning message")
logging.error("This is an error message")
# Out:
# WARNING:root:This is a warning message
# ERROR:root:This is an error message

# %%
import logging

# 로거 생성 및 로깅 레벨 설정
logger = logging.getLogger('my_logger')
logger.setLevel(logging.DEBUG)

# 파일 핸들러 생성 및 로거에 추가
file_handler = logging.FileHandler('example.log')
logger.addHandler(file_handler)

# 로깅 메시지 작성
logger.debug("Debug message")
logger.info("Info message")
logger.error("Error message")
# Out:
# DEBUG:my_logger:Debug message
# INFO:my_logger:Info message
# ERROR:my_logger:Error message

# %%
import logging

# 로거 생성 및 로깅 레벨 설정
logger = logging.getLogger('my_custom_logger')
logger.setLevel(logging.INFO)

# 핸들러 생성 및 포맷터 설정
handler = logging.StreamHandler()
formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
handler.setFormatter(formatter)
logger.addHandler(handler)

# 로깅 메시지 작성
logger.info("This is a custom log message")
# Out:
# 2024-03-05 02:44:55,759 - my_custom_logger - INFO - This is a custom log message
# 2024-03-05 02:44:55,759 - my_custom_logger - INFO - This is a custom log message
# INFO:my_custom_logger:This is a custom log message
